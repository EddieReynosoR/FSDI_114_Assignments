# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class SinglyLinkedList:
    def __init__(self):
        self.head = None
        
    def is_empty(self):
        return self.head == None
        
        
    def append(self, value):
        if not self.head:
            self.head = Node(value)
        else:
            current = self.head
            while current.next: # while current.next != None
                current = current.next
            current.next = Node(value)
            
    def insert(self, index, value):
        if not self.head:
            self.head = Node(value)
            
        elif index <= 0:
            new_node = Node(value)
            new_node.next = self.head
            self.head = new_node
            
        else:
            prev = None
            current = self.head
            counter = 0
            while current.next and counter != index:
                prev = current
                current = current.next
                counter += 1
            if counter != index:
                current.next = Node(value)
            else:
                new_node = Node(value)
                prev.next = new_node
                new_node.next = current
                
    def deleteNode(self, key):
        current = self.head
 
        if current:
            if (current.data == key):
                self.head = current.next
                current = None
                return
        while current:
            if current.data == key:
                break
            prev = current
            current = current.next
        if current == None:
            return
        prev.next = current.next
        current = None
                
    def __str__(self):
        out_str = "["
        if self.head:
            current = self.head
            out_str += "%s" % current.data
            while current:     # while current is not None
                current = current.next
                if current:
                    out_str += ", %s" % current.data
        out_str += "]"
        return out_str
                
    def sum(self):
        total = 0
        current = self.head
        
        while current:
            total += current.data
            current = current.next
        return total

# %%
# PSEUDOCODE

# define function insert (parameters: self, index, value)
#     define variable position equals 0
#     if index equals 0:
#          self.head = Node(value)
#     else if index is higher than 0 and is lower the size of the list
#          current <- head
#          count <- current.index
#
#          while current.index has value
#               add +1 to the count
#               current = current.next
#               if count equals index-1:
#                    assign the value to the current Node
#                    
#               
#               
#          
#
#
#     else if index equals the size of the list:
#          current <- head
#          while current.next is not None
#               current items equals next item
#          current.next <- Node(value)

# %%
sll = SinglyLinkedList()

for number in range(101):
    sll.append(number)
    
print(sll.sum())

def list_function(mylist=[1, 2, 3, 4, 5]):
    listI = SinglyLinkedList()
    for value in mylist:
        listI.append(value)
        print("Current list: ")
        print(listI)
        
    print("Insert: ")
    listI.insert(2,10)
    print(listI)
    
    print("Delete value 1: ")
    listI.deleteNode(1)
    print(listI)
    
    print("Delete value 3: ")
    listI.deleteNode(3)
    print(listI)
    
    print("Delete value 4: ")
    listI.deleteNode(4)
    print(listI)
    
    print("Delete value 2: ")
    listI.deleteNode(2)
    print(listI)
    
    print("Delete value 5: ")
    listI.deleteNode(5)
    print(listI)
    
    print("Delete value 10: ")
    listI.deleteNode(10)
    print(listI)
    
    
    print("Is empty: ", listI.is_empty())
    
        
list_function()
# Out:
# 5050
# Current list:
# [1]
# Current list:
# [1, 2]
# Current list:
# [1, 2, 3]
# Current list:
# [1, 2, 3, 4]
# Current list:
# [1, 2, 3, 4, 5]
# Insert:
# [1, 2, 10, 3, 4, 5]
# Delete value 1:
# [2, 10, 3, 4, 5]
# Delete value 3:
# [2, 10, 4, 5]
# Delete value 4:
# [2, 10, 5]
# Delete value 2:
# [10, 5]
# Delete value 5:
# [10]
# Delete value 10:
# []
# Is empty:  True

# %%
class DNode:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.Next = None
        
class DoublyLinkedList:
    def __init__(self):
        self.head = None
        
    def append(self, value):
        if not self.head:
            self.head = DNode(value)
        else:
            current = self.head
            while current.next:
                current = current.next
            new_node = DNode(value)
            current.next = new_node
            new_node.prev = current
            
    def remove(self, value):
        found = False
        if self.head:    
            current = self.head
            while current and current.data != value:
                current = current.next
            if current == self.head:
                self.head = None 
            elif current.data == value:
                found = True
                prev_node = current.prev # None
                next_node = current.next # None
                prev_node.next = next_node
                next_node.prev = prev_node
        
        if not found:
            raise ValueError("List empty")
